# %% [markdown]
# # Run GenX

# %%
using Pkg
Pkg.activate("/Users/tedwhite15/Documents/Taylers_Files/Research/Projects/Land-use/AVLU_project/NYS-Land-Use/running_GenX/tests/Badyn_test/")
# Out:
#   Activating new project at `~/Documents/Taylers_Files/Research/Projects/Land-use/AVLU_project/GenX/NY_2040_Model/tests/Badyn_test`

# %%
include("Run.jl")
# Out:
#   ____           __  __   _ _
#  / ___| ___ _ __ \ \/ /  (_) |
# | |  _ / _ \ '_ \ \  /   | | |
# | |_| |  __/ | | |/  \ _ | | |
#  \____|\___|_| |_/_/\_(_)/ |_|
#                        |__/
#  Version: 0.4.4
#
# Configuring Settings
# Configuring Solver
# Loading Inputs
# Reading Input CSV Files
# ┌ Warning: Specifying the network map as a matrix is deprecated as of v0.4
# │ and will be removed in v0.5. Instead, use the more compact list-style format.
# │
# │ ..., Network_Lines, Start_Zone, End_Zone, ...
# │                  1,          1,        2,
# │                  2,          1,        3,
# │                  3,          2,        3,
# └ @ GenX /Users/tedwhite15/.julia/packages/GenX/SND5y/src/load_inputs/load_network_data.jl:175
# Network.csv Successfully Read!
# Demand (load) data Successfully Read!
# Fuels_data.csv Successfully Read!
# ┌ Info: Hydro.csv Successfully Read.
# └ @ GenX /Users/tedwhite15/.julia/packages/GenX/SND5y/src/load_inputs/load_resources_data.jl:333
# ...
